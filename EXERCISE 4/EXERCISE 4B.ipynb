# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# We will firstly load the gold layer data files
gold_movies_path = r'C:\Users\Dell E7440\Desktop\GOLD_MOVIES'


# Load the datasets
director_count = pd.read_csv(f'{gold_movies_path}\\director_count.csv')
average_ratings = pd.read_csv(f'{gold_movies_path}\\average_ratings.csv')
actor_count = pd.read_csv(f'{gold_movies_path}\\actor_count.csv')
unique_movies = pd.read_csv(f'{gold_movies_path}\\unique_movies.csv')
average_ratings_small = pd.read_csv(f'{gold_movies_path}\\average_ratings_small.csv')

# Check the data loaded
print("Director Count DataFrame:")
print(director_count.head())
print("\nAverage Ratings DataFrame:")
print(average_ratings.head())
print("\nActor Count DataFrame:")
print(actor_count.head())
print("\nUnique Movies DataFrame:")
print(unique_movies.head())
print("\nAverage Ratings Small DataFrame:")
print(average_ratings_small.head())

# This is the style tha will will use for Seaborn
sns.set(style='whitegrid')
# Out:
# Director Count DataFrame:
#            director  film_count
# 0           Unknown         887
# 1         John Ford          66
# 2    Michael Curtiz          65
# 3     Werner Herzog          54
# 4  Alfred Hitchcock          53
#
# Average Ratings DataFrame:
#    movie_id  user_rating
# 0         1     3.888157
# 1         2     3.236953
# 2         3     3.175550
# 3         4     2.875713
# 4         5     3.079565
#
# Actor Count DataFrame:
#        main_actor  film_count
# 0         Unknown        2418
# 1      John Wayne          94
# 2     Jackie Chan          73
# 3    Nicolas Cage          60
# 4  Robert De Niro          56
#
# Unique Movies DataFrame:
#    adult      budget                                      homepage    id  \
# 0  False  30000000.0          http://toystory.disney.com/toy-story   862
# 1  False  65000000.0                                   No Homepage  8844
# 2  False  60000000.0                                   No Homepage   949
# 3  False  58000000.0  http://www.mgm.com/view/movie/757/Goldeneye/   710
# 4  False  98000000.0                                   No Homepage  1408
#
#      imdb_id original_language    original_title  popularity  \
# 0  tt0114709                en         Toy Story   21.946943
# 1  tt0113497                en           Jumanji   17.015539
# 2  tt0113277                en              Heat   17.924927
# 3  tt0113189                en         GoldenEye   14.686036
# 4  tt0112760                en  Cutthroat Island    7.284477
#
#   production_companies                               production_countries  \
# 0           No Company                       ['United States of America']
# 1           No Company                       ['United States of America']
# 2           No Company                       ['United States of America']
# 3           No Company     ['United Kingdom', 'United States of America']
# 4           No Company  ['France', 'Germany', 'Italy', 'United States ...
#
#    ...  vote_average  vote_count                               genre_names  \
# 0  ...           7.7      5415.0         ['Animation', 'Comedy', 'Family']
# 1  ...           6.9      2413.0        ['Adventure', 'Fantasy', 'Family']
# 2  ...           7.7      1886.0  ['Action', 'Crime', 'Drama', 'Thriller']
# 3  ...           6.6      1194.0       ['Adventure', 'Action', 'Thriller']
# 4  ...           5.7       137.0                   ['Action', 'Adventure']
#
#          collection_name  collection_id  release_year  user_id movie_id  \
# 0   Toy Story Collection          10194        1995.0     1923      862
# 1          No Collection              0        1995.0     7016     8844
# 2          No Collection              0        1995.0      174      949
# 3  James Bond Collection            645        1995.0      619      710
# 4          No Collection              0        1995.0       15     1408
#
#   user_rating            timestamp
# 0         3.0  1997-03-14 10:23:26
# 1         4.0  2009-11-04 16:30:29
# 2         4.0  2000-04-29 02:43:16
# 3         3.0  1996-05-09 02:31:59
# 4         5.0  2012-08-26 19:18:34
#
# [5 rows x 25 columns]
#
# Average Ratings Small DataFrame:
#    movie_id  user_rating
# 0         1     3.872470
# 1         2     3.401869
# 2         3     3.161017
# 3         4     2.384615
# 4         5     3.267857

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.54.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell e7440\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
#BAR CHARTS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# Load the gold layer data files
gold_movies_path = r'C:\Users\Dell E7440\Desktop\GOLD_MOVIES'

# Load the Unique Movies dataset
unique_movies = pd.read_csv(f'{gold_movies_path}\\unique_movies.csv')

# Exploding the genres into separate rows
unique_movies['genre_names'] = unique_movies['genre_names'].apply(eval)  
unique_movies_exploded = unique_movies.explode('genre_names')

# Counting the occurrences of each genre
genre_counts = unique_movies_exploded['genre_names'].value_counts().reset_index()
genre_counts.columns = ['genre_name', 'movie_count']

# Selecting the top 5 genres with the highest movie count
top_5_genres = genre_counts.nlargest(5, 'movie_count')

# Displaying the top 5 genres
print(top_5_genres)

# Plotting the top 5 genres as a horizontal bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=top_5_genres, y='genre_name', x='movie_count', hue='genre_name', palette='mako', legend=False)
plt.title('Top 5 Genres with Highest Movie Count')
plt.ylabel('Genre Name')
plt.xlabel('Movie Count')
plt.tight_layout()
plt.show()
# Out:
#   genre_name  movie_count
# 0      Drama         3721
# 1     Comedy         2111
# 2   Thriller         1425
# 3    Romance         1205
# 4     Action         1175

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Unique Movies dataset
gold_movies_path = r'C:\Users\Dell E7440\Desktop\GOLD_MOVIES'
unique_movies = pd.read_csv(f'{gold_movies_path}\\unique_movies.csv')

# Sort the movies by popularity and select the top 5
top_5_movies = unique_movies.sort_values(by='popularity', ascending=False).head(5)

# Set the Seaborn style
sns.set(style='whitegrid')

# Create a figure and axes
plt.figure(figsize=(12, 6))

# Plotting the top 5 movies as a horizontal bar chart with a light palette
bars = plt.barh(top_5_movies['original_title'], top_5_movies['popularity'], color=sns.light_palette("skyblue", reverse=True, as_cmap=False))


plt.title('Top 5 Movies by Popularity', fontsize=16, pad=20)
plt.xlabel('Popularity', fontsize=14)
plt.ylabel('Original Title', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)


plt.tight_layout()  
plt.show()

# %%
#We will code for Movies with the Highest Budget and User Rating and put them in a bar chart

import pandas as pd
import matplotlib.pyplot as plt

# Load the Unique Movies dataset
gold_movies_path = r'C:\Users\Dell E7440\Desktop\GOLD_MOVIES'
unique_movies = pd.read_csv(f'{gold_movies_path}\\unique_movies.csv')

# Get the top 5 movies with the highest budget
top_5_budget = unique_movies.nlargest(5, 'budget')

# Plotting the budget and user rating for the top 5 movies as a horizontal bar chart
plt.figure(figsize=(12, 6))

# Create two horizontal bars, one for budget and one for user rating
plt.barh(top_5_budget['original_title'], top_5_budget['budget'], color='#AEEEEE', label='Budget')  # Light Cyan
plt.barh(top_5_budget['original_title'], top_5_budget['user_rating'] * 10000000, color='#FFB6C1', label='User Rating', alpha=0.6)  # Light Pink

plt.title('Top 5 Movies by Budget and User Rating', fontsize=12)
plt.xlabel('Value', fontsize=10)
plt.ylabel('Original Title', fontsize=10)
plt.grid(axis='x')
plt.legend()


plt.tight_layout()  
plt.show()

# %%
# We will print the first 5 rows of each file in order to check their structure approximately

print("First 5 rows of average_rating_over_time:")
print(average_rating_over_time.head())

print("\nFirst 5 rows of genre_average_ratings:")
print(genre_average_ratings.head())

print("\nFirst 5 rows of genre_movie_count:")
print(genre_movie_count.head())

print("\nFirst 5 rows of top_rated_movies_by_genre:")
print(top_rated_movies_by_genre.head())

print("\nFirst 5 rows of top_rated_movies:")
print(top_rated_movies.head())
# Out:
# First 5 rows of average_rating_over_time:
#         genres_name  release_year    rating
# 0            Action        2003.0  5.000000
# 1            Action        2004.0  2.694444
# 2            Action        2010.0  3.500000
# 3  Action Adventure        1972.0  3.650000
# 4  Action Adventure        1995.0  3.616279
#
# First 5 rows of genre_average_ratings:
#                                          genres_name    rating
# 0                                             Action  2.880952
# 1                                   Action Adventure  3.639098
# 2                         Action Adventure Animation       NaN
# 3           Action Adventure Animation Comedy Family       NaN
# 4  Action Adventure Animation Comedy Family Fanta...       NaN
#
# First 5 rows of genre_movie_count:
#             genre  movie_count
# 0          Comedy          607
# 1           Drama          581
# 2   Drama Romance          251
# 3    Comedy Drama          215
# 4  Comedy Romance          198
#
# First 5 rows of top_rated_movies_by_genre:
#                                     genres_name  \
# 0                                        Action
# 1                              Action Adventure
# 2            Action Adventure Animation Fantasy
# 3                       Action Adventure Comedy
# 4  Action Adventure Comedy Crime Drama Thriller
#
#                                 title  rating
# 0          once upon a time in mexico     5.0
# 1                    cutthroat island     5.0
# 2  final fantasy vii: advent children     5.0
# 3                         three kings     1.5
# 4                     the ice harvest     2.5
#
# First 5 rows of top_rated_movies:
#                                   title  rating
# 0                        manitou's shoe     5.0
# 1  the chronicles of riddick: dark fury     5.0
# 2                      cutthroat island     5.0
# 3              the gendarme in new york     5.0
# 4                                 sissi     5.0

# %%
# 3 LINE PLOTS

# %%
#Let us create a line plot that shows the number of films produced per year

import pandas as pd
import matplotlib.pyplot as plt

# Load the data
unique_movies = pd.read_csv(r'C:\Users\Dell E7440\Desktop\GOLD_MOVIES\unique_movies.csv')

# Group by release year and count the number of films per year
films_per_year = unique_movies.groupby('release_year').size()

# Apply rolling average with a window of 5 years for smoothing
rolling_films_per_year = films_per_year.rolling(window=5).mean()

# Plot the smoothed line plot
plt.figure(figsize=(12,6))
plt.plot(films_per_year.index, rolling_films_per_year.values, marker='s', linestyle='-', color='g')
plt.title('Number of Films Produced per Year (Smoothed with 5-year Rolling Average)')
plt.xlabel('Release Year')
plt.ylabel('Number of Films')
plt.grid(True)
plt.show()

# %%
#Let us create a line plot that shows the number of film each main actor has played, excluding unkown category


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# Load the datasets
gold_movies_path = r'C:\Users\Dell E7440\Desktop\GOLD_MOVIES'
actor_count = pd.read_csv(f'{gold_movies_path}\\actor_count.csv')

# Filter out "Unknown" actors
actor_count_filtered = actor_count[actor_count['main_actor'] != 'Unknown']

# Sort the filtered DataFrame by film_count and select the top 10 actors
top_actors = actor_count_filtered.sort_values(by='film_count', ascending=False).head(10)

# Create a line plot for actor count vs film count
plt.figure(figsize=(14, 6))
sns.lineplot(x='main_actor', y='film_count', data=top_actors, marker='o')
plt.title('Top 10 Actors by Film Count (Excluding Unknown)', fontsize=16)
plt.xlabel('Main Actor', fontsize=14)
plt.ylabel('Film Count', fontsize=14)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Merge average_ratings with unique_movies
avg_ratings_over_time = pd.merge(average_ratings, unique_movies[['id', 'release_year']], left_on='movie_id', right_on='id')

# Group by release_year and calculate mean rating
avg_rating_by_year = avg_ratings_over_time.groupby('release_year')['user_rating'].mean().reset_index()

# Plot
plt.figure(figsize=(12, 6))
plt.plot(avg_rating_by_year['release_year'], avg_rating_by_year['user_rating'], marker='o')
plt.title('Average Ratings Over Time')
plt.xlabel('Release Year')
plt.ylabel('Average User Rating')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
#PIE CHARTS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# Load the gold layer data files
gold_movies_path = r'C:\Users\Dell E7440\Desktop\GOLD_MOVIES'


# Set the style for seaborn
sns.set(style='whitegrid')

# Pie Chart 1: Distribution of Original Titles
plt.figure(figsize=(10, 8))
top_titles = unique_movies['original_title'].value_counts()[:10]  # Get top 10 original titles
plt.pie(top_titles, labels=top_titles.index, autopct='%1.1f%%', colors=sns.color_palette("pastel"))
plt.title('Top 10 Original Titles by Count')
plt.show()

# %%
# Let us code for a Pie Chart that shows Distribution of Top 5 Original Languages

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

plt.figure(figsize=(10, 8))
language_counts = unique_movies['original_language'].value_counts()[:5]  # Get top 5 original languages
plt.pie(language_counts, labels=language_counts.index, autopct='%1.1f%%', colors=sns.color_palette("pastel"))
plt.title('Top 5 Original Languages by Count')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# Load the Unique Movies data (replace the path with your actual file path)
unique_movies = pd.read_csv(r'C:\Users\Dell E7440\Desktop\GOLD_MOVIES\unique_movies.csv')

# Count occurrences of production countries
production_countries = unique_movies['production_countries'].apply(eval).explode()

# Count the number of films per country
country_counts = Counter(production_countries)

# Create a DataFrame from the counts and sort by 'film_count' to get the top 5
production_countries_df = pd.DataFrame(country_counts.items(), columns=['production_countries', 'film_count'])
top_5_countries_df = production_countries_df.nlargest(5, 'film_count')

# Pie Chart: Top 5 Production Countries Distribution
plt.figure(figsize=(8, 8))
plt.pie(top_5_countries_df['film_count'], labels=top_5_countries_df['production_countries'], 
        autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Top 5 Production Countries Distribution')
plt.show()

# %%
# Three other chart types

# %%
#Show the distribution of average user ratings across all movies with an histogram

plt.figure(figsize=(12, 6))
plt.hist(average_ratings['user_rating'], bins=20, color='lightblue', edgecolor='black')
plt.title('Distribution of Average User Ratings')
plt.xlabel('User Rating')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
#We will code for a correlation matrix heatmap between our numerical variables and check their relation.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Unique Movies dataset
gold_movies_path = r'C:\Users\Dell E7440\Desktop\GOLD_MOVIES'
unique_movies = pd.read_csv(f'{gold_movies_path}\\unique_movies.csv')

# Select relevant numerical columns for correlation
correlation_data = unique_movies[['budget', 'popularity', 'vote_average', 'user_rating']]

# Calculate the correlation matrix
correlation_matrix = correlation_data.corr()

# Create heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Matrix Heatmap', fontsize=16)
plt.show()

# %%
#Let us create a box plot that shows the : Distribution of Movie Ratings by Release Year (2011-2020) 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# Ignore warnings
warnings.filterwarnings('ignore')

# Load the dataset
gold_movies_path = r'C:\Users\Dell E7440\Desktop\GOLD_MOVIES'
unique_movies = pd.read_csv(f'{gold_movies_path}\\unique_movies.csv')

# Filter out movies without a release year or vote average
unique_movies_filtered = unique_movies.dropna(subset=['release_year', 'vote_average'])

# Filter data for the last 10 years (e.g., 2011 to 2020)
unique_movies_filtered = unique_movies_filtered[(unique_movies_filtered['release_year'] >= 2011) &
                                                (unique_movies_filtered['release_year'] <= 2020)]

# Create a box plot for vote_average over release_year (Last ten years)
plt.figure(figsize=(12, 6))
sns.boxplot(x='release_year', y='vote_average', data=unique_movies_filtered, palette="Set2")

# Set titles and labels
plt.title(' Distribution of Movie Ratings by Release Year (2011-2020)', fontsize=16)
plt.xlabel('Release Year', fontsize=14)
plt.ylabel('Average Vote', fontsize=14)  # Updated Y-axis label

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()
